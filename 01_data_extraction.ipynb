# %% [markdown]
# ###1. Instalar yfinance

# %%
# !pip install yfinance

# %% [markdown]
# ###2. Importar librerías

# %%
import yfinance as yf
import pandas as pd
import os

# %% [markdown]
# ###3. Crear carpetas

# %%
os.makedirs("data/raw", exist_ok=True)

# %% [markdown]
# ###4. Definir los activos

# %%
tickers = ["^GSPC", "^IXIC", "MXN=X", "^MXX"]

# %% [markdown]
# ###5. Descargar los datos

# %%
data = yf.download(tickers, start="2015-01-01", interval="1d")
data.head()
# Out:
# /tmp/ipython-input-69377193.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start="2015-01-01", interval="1d")
# [*********************100%***********************]  4 of 4 completed
# Price          Close                                              High  \
# Ticker         MXN=X        ^GSPC        ^IXIC          ^MXX     MXN=X
# Date
# 2015-01-01  14.75279          NaN          NaN           NaN  14.75790
# 2015-01-02  14.82043  2058.199951  4726.810059  42115.468750  14.86300
# 2015-01-05  14.93942  2020.579956  4652.569824  41099.371094  14.98250
# 2015-01-06  14.89467  2002.609985  4592.740234  41329.410156  14.98967
# 2015-01-07  14.71020  2025.900024  4650.470215  41813.929688  14.91380
#
# Price                                                    Low               \
# Ticker            ^GSPC        ^IXIC          ^MXX     MXN=X        ^GSPC
# Date
# ...

# %%
from google.colab import files

files.download("data/raw/market_data.csv")
